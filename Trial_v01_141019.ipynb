# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt


class betco:


    class preproc:
        
        def __init__(self):
            return

        class import_:
    
            def __init__(self):
                return

            def Pgw(): 
                return

            def Pbaro():
                return

            def rainfall():
                return

            def stage():
                return

            def extraction():
                return
        
        def remove_outliers():
            return

        def fill_gaps():
            return

        def calc_fwhead():
            return
 
 
    class proc:
        
        def __init__(self):
            return

        class time_domain:
                
            def __init__(self):
                return

            def calc_linear():
                return
                
            def calc_nonlin():
                return
            
            def extract_fns():
                return
                
            def calc_amps():
                return

        class freq_domain:
        
            def __init__(self):
                return

            def compare_amps():
                return

            class dft:
                
                def __init__(self):
                    return

                def calc_amps():
                    return
                
            class cwt:
                
                def __init__(self):
                    return

                def calc_amps():
                    return
                    

    class postproc:
    
        def __init__(self):
            return

        def estimate_params():
            return
            
        def compare_magnitudes():
            return
            
        def compare_heads():
            return
